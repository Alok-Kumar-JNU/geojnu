# %%
import geojnu

# %%
m=geojnu.map()

# %%
url="https://github.com/opengeos/datasets/releases/download/world/countries.json"
m.add_vector(url,zoom_to_layer=False)
m
# Out:
# map(bottom=850.0, center=[29.22889003019423, 136.75781250000003], controls=(ZoomControl(options=['position', '…
