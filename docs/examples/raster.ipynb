# %%
import geojnu

# %%
m=geojnu.map()
filepath="https://github.com/opengeos/datasets/releases/download/raster/dem_90m.tif"
m.add_raster(filepath, name="dem_90m", opacity=0.5)

# %%
m
# Out:
# map(center=[37.630466999999996, -119.03021849999999], controls=(ZoomControl(options=['position', 'zoom_in_text…
