# %%
import geojnu

# %%
m=geojnu.map()
filepath="https://github.com/opengeos/datasets/releases/download/raster/Libya-2023-09-13_clip.tif"
m.add_raster(filepath, name="Libya", opacity=0.5)
m
# Out:
# map(center=[32.7684025, 22.640009499999998], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…
