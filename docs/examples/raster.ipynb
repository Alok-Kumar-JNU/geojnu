# %%
import geojnu

# %%
m = geojnu.map()
m
# Out:
# map(center=[25, 75], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
data="https://github.com/opengeos/datasets/releases/download/raster/dem_90m.tif"

# %%
m.add_raster(data)
