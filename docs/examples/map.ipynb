# %% [markdown]
# # Create Interactive map
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alokjnu/geojnu/blob/main/docs/examples/map.ipynb)

# %%
import geojnu.foliummap as geojnu

# %%
m = geojnu.Map()
url = "https://github.com/opengeos/datasets/releases/download/us/us_southeast.geojson"
m.add_vector(url, zoom_to_layer=False)
m

# %%
import geojnu

# %%
m = geojnu.map()
url = "https://github.com/opengeos/datasets/releases/download/us/us_southeast.geojson"
m.add_vector(url, zoom_to_layer=False)
m

# %%
m.add_basemap(basemap="NASAGIBS.ModisTerraTrueColorCR")

# %%
m1 = geojnu.map()

# %%
m1.google_map(map_type="Roadmap")

# %%
m1

# %%
from geojnu.common import hello_world

# %%
hello_world()
